# %%
import pandas as np
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_18640\3052129075.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as np

# %%
import pandas as pd

titanic_df = pd.read_csv(r'R:\MATERI PERKULIAHAN\SEMESTER 4\Bigdata\titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

def show_middle(df, n):
    total_rows = len(df)
    if n >= total_rows:
        return df
    
    start = (total_rows - n) // 2
    end = start + n
    return df.iloc[start:end]

# %%
show_middle(titanic_df, 7)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 442          443         0       3          Petterson, Mr. Johan Emil    male
# 443          444         1       2          Reynaldo, Ms. Encarnacion  female
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt    male
# 445          446         1       1          Dodge, Master. Washington    male
# 446          447         1       2  Mellinger, Miss. Madeleine Violet  female
# 447          448         1       1        Seward, Mr. Frederic Kimber    male
# 448          449         1       3     Baclini, Miss. Marie Catherine  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 442  25.0      1      0  347076   7.7750   NaN        S
# 443  28.0      0      0  230434  13.0000   NaN        S
# 444   NaN      0      0   65306   8.1125   NaN        S
# 445   4.0      0      2   33638  81.8583   A34        S
# 446  13.0      0      1  250644  19.5000   NaN        S
# ...
